# %% [markdown]
# <a href="https://colab.research.google.com/github/shrutisingh004/Deep-Learning/blob/main/GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_dataset = datasets.CIFAR10(root='./data',\
              train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
                                batch_size=32, shuffle=True)
# Out:
# 100%|██████████| 170M/170M [00:23<00:00, 7.41MB/s]

# %%
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
        nn.ZeroPad2d((0, 1, 0, 1)),
        nn.BatchNorm2d(64, momentum=0.82),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(128, momentum=0.82),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(256, momentum=0.8),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Flatten(),
        nn.Linear(256 * 5 * 5, 1),
        nn.Sigmoid()
    )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %%
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)

adversarial_loss = nn.BCELoss()

optimizer_G = optim.Adam(generator.parameters()\
                         , lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
                         , lr=lr, betas=(beta1, beta2))

# %%
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):
        real_images = batch[0].to(device)
        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)
        real_images = real_images.to(device)
        optimizer_D.zero_grad()
        z = torch.randn(real_images.size(0), latent_dim, device=device)
        fake_images = generator(z)
        real_loss = adversarial_loss(discriminator\
                                     (real_images), valid)
        fake_loss = adversarial_loss(discriminator\
                                     (fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2
        d_loss.backward()
        optimizer_D.step()
        optimizer_G.zero_grad()
        gen_images = generator(z)
        g_loss = adversarial_loss(discriminator(gen_images), valid)
        g_loss.backward()
        optimizer_G.step()
        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.4962 Generator Loss: 1.2014
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.6513 Generator Loss: 0.9460
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.6441 Generator Loss: 0.9150
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.3978 Generator Loss: 1.4941
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.7391 Generator Loss: 0.9892
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.6682 Generator Loss: 0.8887
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.8039 Generator Loss: 0.6945
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.7759 Generator Loss: 0.7739
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.6270 Generator Loss: 0.9544
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.7746 Generator Loss: 0.7748
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.5652 Generator Loss: 0.9109
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.6337 Generator Loss: 0.7979
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.7524 Generator Loss: 0.9562
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.6386 Generator Loss: 0.9813
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.5719 Generator Loss: 1.2724
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.7140 Generator Loss: 1.0441
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.5928 Generator Loss: 0.9373
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.7270 Generator Loss: 0.8877
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.5655 Generator Loss: 1.0220
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.5161 Generator Loss: 1.4007
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.5670 Generator Loss: 1.0890
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.6495 Generator Loss: 0.9178
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.5606 Generator Loss: 0.8318
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.7713 Generator Loss: 0.6765
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.6323 Generator Loss: 1.1425
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.6691 Generator Loss: 1.1996
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.4989 Generator Loss: 1.0747
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.6554 Generator Loss: 0.9497
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.5282 Generator Loss: 1.2294
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.6215 Generator Loss: 0.9910
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.5550 Generator Loss: 1.3111
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.7337 Generator Loss: 1.3296
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.5207 Generator Loss: 1.2040
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.6815 Generator Loss: 1.0377
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.8481 Generator Loss: 0.8011
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.6748 Generator Loss: 0.9494
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.8480 Generator Loss: 0.9134
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.6317 Generator Loss: 1.0984
# Epoch [3/10]                        Batch 900/1563 Discriminator Loss: 0.5472 Generator Loss: 1.2329
# Epoch [3/10]                        Batch 1000/1563 Discriminator Loss: 0.6456 Generator Loss: 1.0185
# Epoch [3/10]                        Batch 1100/1563 Discriminator Loss: 0.4661 Generator Loss: 1.3020
# Epoch [3/10]                        Batch 1200/1563 Discriminator Loss: 0.7944 Generator Loss: 0.8837
# Epoch [3/10]                        Batch 1300/1563 Discriminator Loss: 0.6258 Generator Loss: 1.4647
# Epoch [3/10]                        Batch 1400/1563 Discriminator Loss: 0.6383 Generator Loss: 1.0089
# Epoch [3/10]                        Batch 1500/1563 Discriminator Loss: 0.6783 Generator Loss: 1.0780
# Epoch [4/10]                        Batch 100/1563 Discriminator Loss: 0.4912 Generator Loss: 1.5953
# Epoch [4/10]                        Batch 200/1563 Discriminator Loss: 0.7633 Generator Loss: 0.6013
# Epoch [4/10]                        Batch 300/1563 Discriminator Loss: 0.4596 Generator Loss: 1.4084
# Epoch [4/10]                        Batch 400/1563 Discriminator Loss: 0.7245 Generator Loss: 0.9356
# Epoch [4/10]                        Batch 500/1563 Discriminator Loss: 0.5654 Generator Loss: 1.2224
# Epoch [4/10]                        Batch 600/1563 Discriminator Loss: 0.7098 Generator Loss: 0.7378
# Epoch [4/10]                        Batch 700/1563 Discriminator Loss: 0.5042 Generator Loss: 1.1994
# Epoch [4/10]                        Batch 800/1563 Discriminator Loss: 0.7198 Generator Loss: 1.4614
# Epoch [4/10]                        Batch 900/1563 Discriminator Loss: 0.6564 Generator Loss: 1.3037
# Epoch [4/10]                        Batch 1000/1563 Discriminator Loss: 0.4895 Generator Loss: 1.5192
# Epoch [4/10]                        Batch 1100/1563 Discriminator Loss: 0.6226 Generator Loss: 1.5380
# Epoch [4/10]                        Batch 1200/1563 Discriminator Loss: 0.6241 Generator Loss: 1.0628
# Epoch [4/10]                        Batch 1300/1563 Discriminator Loss: 0.7307 Generator Loss: 0.8276
# Epoch [4/10]                        Batch 1400/1563 Discriminator Loss: 0.4863 Generator Loss: 1.2781
# Epoch [4/10]                        Batch 1500/1563 Discriminator Loss: 0.7878 Generator Loss: 1.4003
# Epoch [5/10]                        Batch 100/1563 Discriminator Loss: 0.5013 Generator Loss: 1.4279
# Epoch [5/10]                        Batch 200/1563 Discriminator Loss: 0.6015 Generator Loss: 1.0686
# Epoch [5/10]                        Batch 300/1563 Discriminator Loss: 0.5986 Generator Loss: 1.5405
# Epoch [5/10]                        Batch 400/1563 Discriminator Loss: 0.4750 Generator Loss: 1.0595
# Epoch [5/10]                        Batch 500/1563 Discriminator Loss: 0.5951 Generator Loss: 0.9437
# Epoch [5/10]                        Batch 600/1563 Discriminator Loss: 0.5345 Generator Loss: 1.2805
# Epoch [5/10]                        Batch 700/1563 Discriminator Loss: 0.6558 Generator Loss: 1.4086
# Epoch [5/10]                        Batch 800/1563 Discriminator Loss: 0.5894 Generator Loss: 1.0320
# Epoch [5/10]                        Batch 900/1563 Discriminator Loss: 0.5251 Generator Loss: 1.2564
# Epoch [5/10]                        Batch 1000/1563 Discriminator Loss: 0.7414 Generator Loss: 0.7482
# Epoch [5/10]                        Batch 1100/1563 Discriminator Loss: 0.6512 Generator Loss: 0.9726
# Epoch [5/10]                        Batch 1200/1563 Discriminator Loss: 0.5545 Generator Loss: 1.3393
# Epoch [5/10]                        Batch 1300/1563 Discriminator Loss: 0.6717 Generator Loss: 1.0794
# Epoch [5/10]                        Batch 1400/1563 Discriminator Loss: 0.7091 Generator Loss: 1.1595
# Epoch [5/10]                        Batch 1500/1563 Discriminator Loss: 0.5416 Generator Loss: 1.3029
# Epoch [6/10]                        Batch 100/1563 Discriminator Loss: 0.5574 Generator Loss: 1.0240
# Epoch [6/10]                        Batch 200/1563 Discriminator Loss: 0.4263 Generator Loss: 1.7971
# Epoch [6/10]                        Batch 300/1563 Discriminator Loss: 0.5454 Generator Loss: 0.9189
# Epoch [6/10]                        Batch 400/1563 Discriminator Loss: 0.6720 Generator Loss: 0.8534
# Epoch [6/10]                        Batch 500/1563 Discriminator Loss: 0.5972 Generator Loss: 1.0793
# Epoch [6/10]                        Batch 600/1563 Discriminator Loss: 0.6127 Generator Loss: 0.9335
# Epoch [6/10]                        Batch 700/1563 Discriminator Loss: 0.6271 Generator Loss: 1.3332
# Epoch [6/10]                        Batch 800/1563 Discriminator Loss: 0.6701 Generator Loss: 1.0402
# Epoch [6/10]                        Batch 900/1563 Discriminator Loss: 0.6148 Generator Loss: 1.5701
# Epoch [6/10]                        Batch 1000/1563 Discriminator Loss: 0.4988 Generator Loss: 1.1881
# Epoch [6/10]                        Batch 1100/1563 Discriminator Loss: 0.5325 Generator Loss: 1.5021
# Epoch [6/10]                        Batch 1200/1563 Discriminator Loss: 0.4318 Generator Loss: 0.9461
# Epoch [6/10]                        Batch 1300/1563 Discriminator Loss: 0.7803 Generator Loss: 0.8326
# Epoch [6/10]                        Batch 1400/1563 Discriminator Loss: 0.7482 Generator Loss: 0.9307
# Epoch [6/10]                        Batch 1500/1563 Discriminator Loss: 0.5601 Generator Loss: 1.3998
# Epoch [7/10]                        Batch 100/1563 Discriminator Loss: 0.7081 Generator Loss: 1.2215
# Epoch [7/10]                        Batch 200/1563 Discriminator Loss: 0.6725 Generator Loss: 0.8589
# Epoch [7/10]                        Batch 300/1563 Discriminator Loss: 0.7558 Generator Loss: 0.5560
# Epoch [7/10]                        Batch 400/1563 Discriminator Loss: 0.7994 Generator Loss: 0.5653
# Epoch [7/10]                        Batch 500/1563 Discriminator Loss: 0.8872 Generator Loss: 0.8401
# Epoch [7/10]                        Batch 600/1563 Discriminator Loss: 0.5008 Generator Loss: 1.7073
# Epoch [7/10]                        Batch 700/1563 Discriminator Loss: 0.6105 Generator Loss: 1.2249
# Epoch [7/10]                        Batch 800/1563 Discriminator Loss: 0.5640 Generator Loss: 0.9229
# Epoch [7/10]                        Batch 900/1563 Discriminator Loss: 0.6483 Generator Loss: 0.7262
# Epoch [7/10]                        Batch 1000/1563 Discriminator Loss: 0.6274 Generator Loss: 0.6800
# Epoch [7/10]                        Batch 1100/1563 Discriminator Loss: 0.6746 Generator Loss: 1.5290
# Epoch [7/10]                        Batch 1200/1563 Discriminator Loss: 0.7522 Generator Loss: 1.4470
# Epoch [7/10]                        Batch 1300/1563 Discriminator Loss: 0.7389 Generator Loss: 1.9767
# Epoch [7/10]                        Batch 1400/1563 Discriminator Loss: 0.5901 Generator Loss: 1.2096
# Epoch [7/10]                        Batch 1500/1563 Discriminator Loss: 0.5252 Generator Loss: 1.8551
# Epoch [8/10]                        Batch 100/1563 Discriminator Loss: 0.6569 Generator Loss: 1.2589
# Epoch [8/10]                        Batch 200/1563 Discriminator Loss: 0.5162 Generator Loss: 1.1387
# Epoch [8/10]                        Batch 300/1563 Discriminator Loss: 0.6765 Generator Loss: 0.6647
# Epoch [8/10]                        Batch 400/1563 Discriminator Loss: 0.5745 Generator Loss: 1.0911
# Epoch [8/10]                        Batch 500/1563 Discriminator Loss: 0.4422 Generator Loss: 1.3394
# Epoch [8/10]                        Batch 600/1563 Discriminator Loss: 0.4218 Generator Loss: 0.9539
# Epoch [8/10]                        Batch 700/1563 Discriminator Loss: 0.7293 Generator Loss: 1.0187
# Epoch [8/10]                        Batch 800/1563 Discriminator Loss: 0.6720 Generator Loss: 0.9037
# Epoch [8/10]                        Batch 900/1563 Discriminator Loss: 0.3231 Generator Loss: 1.4158
# Epoch [8/10]                        Batch 1000/1563 Discriminator Loss: 0.5069 Generator Loss: 1.5158
# Epoch [8/10]                        Batch 1100/1563 Discriminator Loss: 0.3927 Generator Loss: 0.9369
# Epoch [8/10]                        Batch 1200/1563 Discriminator Loss: 0.5903 Generator Loss: 1.1114
# Epoch [8/10]                        Batch 1300/1563 Discriminator Loss: 0.5900 Generator Loss: 1.0806
# Epoch [8/10]                        Batch 1400/1563 Discriminator Loss: 0.7161 Generator Loss: 1.0164
# Epoch [8/10]                        Batch 1500/1563 Discriminator Loss: 0.6507 Generator Loss: 1.2604
# Epoch [9/10]                        Batch 100/1563 Discriminator Loss: 0.5598 Generator Loss: 1.1641
# Epoch [9/10]                        Batch 200/1563 Discriminator Loss: 0.4002 Generator Loss: 1.7808
# Epoch [9/10]                        Batch 300/1563 Discriminator Loss: 0.7588 Generator Loss: 0.9609
# Epoch [9/10]                        Batch 400/1563 Discriminator Loss: 0.3905 Generator Loss: 1.5554
# Epoch [9/10]                        Batch 500/1563 Discriminator Loss: 0.7017 Generator Loss: 1.3518
# Epoch [9/10]                        Batch 600/1563 Discriminator Loss: 0.4924 Generator Loss: 1.6529
# Epoch [9/10]                        Batch 700/1563 Discriminator Loss: 0.6274 Generator Loss: 1.2096
# Epoch [9/10]                        Batch 800/1563 Discriminator Loss: 0.6618 Generator Loss: 0.9344
# Epoch [9/10]                        Batch 900/1563 Discriminator Loss: 0.6891 Generator Loss: 1.1367
# Epoch [9/10]                        Batch 1000/1563 Discriminator Loss: 0.5591 Generator Loss: 1.7247
# Epoch [9/10]                        Batch 1100/1563 Discriminator Loss: 0.5210 Generator Loss: 1.3226
# Epoch [9/10]                        Batch 1200/1563 Discriminator Loss: 0.5784 Generator Loss: 1.0968
# Epoch [9/10]                        Batch 1300/1563 Discriminator Loss: 0.5285 Generator Loss: 1.2721
# Epoch [9/10]                        Batch 1400/1563 Discriminator Loss: 0.5000 Generator Loss: 1.2111
# Epoch [9/10]                        Batch 1500/1563 Discriminator Loss: 0.5245 Generator Loss: 0.8276
# Epoch [10/10]                        Batch 100/1563 Discriminator Loss: 0.4481 Generator Loss: 1.0618
# Epoch [10/10]                        Batch 200/1563 Discriminator Loss: 0.8401 Generator Loss: 1.4670
# Epoch [10/10]                        Batch 300/1563 Discriminator Loss: 0.5150 Generator Loss: 1.4376
# Epoch [10/10]                        Batch 400/1563 Discriminator Loss: 0.5771 Generator Loss: 1.1767
# Epoch [10/10]                        Batch 500/1563 Discriminator Loss: 0.4075 Generator Loss: 1.0408
# Epoch [10/10]                        Batch 600/1563 Discriminator Loss: 0.4914 Generator Loss: 1.3707
# Epoch [10/10]                        Batch 700/1563 Discriminator Loss: 0.6129 Generator Loss: 1.0789
# Epoch [10/10]                        Batch 800/1563 Discriminator Loss: 0.4147 Generator Loss: 1.2421
# Epoch [10/10]                        Batch 900/1563 Discriminator Loss: 0.7960 Generator Loss: 2.1464
# Epoch [10/10]                        Batch 1000/1563 Discriminator Loss: 0.7681 Generator Loss: 2.3892
# Epoch [10/10]                        Batch 1100/1563 Discriminator Loss: 0.7028 Generator Loss: 1.0361
# Epoch [10/10]                        Batch 1200/1563 Discriminator Loss: 0.8686 Generator Loss: 0.8745
# Epoch [10/10]                        Batch 1300/1563 Discriminator Loss: 0.4769 Generator Loss: 1.8977
# Epoch [10/10]                        Batch 1400/1563 Discriminator Loss: 0.7614 Generator Loss: 0.8748
# Epoch [10/10]                        Batch 1500/1563 Discriminator Loss: 0.7540 Generator Loss: 1.1239
